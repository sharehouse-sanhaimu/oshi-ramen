# %%
from pycirclize import Circos
import pandas as pd

# Create RPG jobs parameter dataframe (3 jobs, 7 parameters)
df = pd.DataFrame(
    data=[
        [1, 2, 3, 3, 4],
    ],
    index=["Nodoguro"],
    columns=["STR", "DEX", "INT", "VIT", "LUK"],
)

# Initialize Circos instance for radar chart plot
circos = Circos.radar_chart(
    df,
    vmax=5,
    marker_size=6,
    grid_interval_ratio=0.2,
)

# Plot figure & set legend on upper right
fig = circos.plotfig()
_ = circos.ax.legend(loc="upper right", fontsize=10)
fig.savefig("/Users/iwakiaoiyou/oshi-ramen/magazine/imgs/radar-chart/example05.png")
